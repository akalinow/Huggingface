# %%
import sys
sys.path.append('/scratch_hdd/akalinow/ProgrammingProjects/Huggingface/SAP2NCN/python/')
from utils import *

import importlib
importlib.reload(sys.modules['utils'])
# Out:
# <module 'utils' from '/scratch_hdd/akalinow/ProgrammingProjects/Huggingface/SAP2NCN/python/utils.py'>

# %% [markdown]
# ## Load the data from xlsx to pandas dataframe

# %%
importlib.reload(sys.modules['utils'])

inputFileName = '/scratch_hdd/akalinow/CMS/OPUS_22/budżet/501-D111-66-0006854_20260210.xlsx'
mapFileName = '/scratch_hdd/akalinow/CMS/OPUS_22/budżet/data/konta_KG.xlsx'
df = loadSAPData(inputFileName, mapFileName)
writeNCNReport(df, inputFileName)
# Out:
# File saved successfully!
